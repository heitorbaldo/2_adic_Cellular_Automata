# %% [markdown]
# # 2-adic Cellular Automata
#
# <hr>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from pyadic import PAdic, ModP
from fractions import Fraction as Q

from functions import *
from two_adic_cellular_automata import *

# %% [markdown]
# ## 2-adic Cellular Automata

# %%
#Run an addictive 2-adic cellular automata.
#Update rule: add the 2-adic number to itself.

run_addictive_2_adic_cellular_automata(Q(7,13), 16)  #Q(7, 13) represents the fraction 7/13; n=16 time steps.

# %%
run_addictive_2_adic_cellular_automata(Q(17,7), 20)  #Q(17, 7) represents the fraction 17/7; n=20 time steps.

# %%
run_addictive_2_adic_cellular_automata(-Q(17,7), 16)  #-Q(17, 7) represents the fraction -17/7; n=16 time steps.

# %%
run_addictive_2_adic_cellular_automata(-7, 16)  #n=16 time steps.

# %%
run_addictive_2_adic_cellular_automata(-7, 16)  #n=16 time steps.

# %%
run_addictive_2_adic_cellular_automata(89, 16)

# %%
run_addictive_2_adic_cellular_automata(-89, 16)

# %%
#Run a multiplicative 2-adic cellular automata.
#Update rule: multiply the 2-adic number to itself.

run_multiplicative_2_adic_cellular_automata(-23, 80)

# %%
run_multiplicative_2_adic_cellular_automata(23, 80)

# %%
run_multiplicative_2_adic_cellular_automata(Q(13, 2), 80)

# %%
run_multiplicative_2_adic_cellular_automata(-19, 80)

# %%
run_multiplicative_2_adic_cellular_automata(47, 70)

# %%
run_multiplicative_2_adic_cellular_automata(Q(17,9), 100)

# %%
run_multiplicative_2_adic_cellular_automata(-Q(17,9), 100)
